# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")                # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/kaggle/input/pubg-winner-prediction/train_V2.csv')

# %%
df.info()

# %%
df.describe()

# %%
df.dtypes

# %%
df.sample(6) #print random six row from the dataset

# %% [markdown]
# # The average person kills how many players? 5. 99% of people have how many kills?  6. The most kills ever recorded are how much?

# %%
print("The average person kills {:.4f} players, 99% of people have {} kills or less, while the most kills ever recorded is {}.".format(df['kills'].mean(),df['kills'].quantile(0.99), df['kills'].max()))

# %%
df.columns

# %%
# set the background style of the plot 
sns.set_style('whitegrid') 
sns.distplot(df['matchDuration'], kde = False, color ='red', bins = 30)

# %%
plt.title("MatchDuration Distance Distribution",fontsize=15)
sns.distplot(df['matchDuration'])
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
# there are two types of maps?
df['matchDuration'].hist(bins=50, ax=ax[0])
df.query('matchDuration >= 1400 & matchDuration <= 1800')['matchDuration'].hist(bins=50, ax=ax[1])

# %%
#min matchDuration
df[df['matchDuration'] == df['matchDuration'].min()].head()

# %%
#max matchDuration
df[df['matchDuration'] == df['matchDuration'].max()].head()

# %%
# set the background style of the plot 
sns.set_style('whitegrid') 
sns.distplot(df['walkDistance'], kde = False, color ='orange', bins = 30)

# %%
plt.title("Walking Distance Distribution",fontsize=15)
sns.distplot(df['walkDistance'])
plt.show()

# %%
fig,axs=plt.subplots(2,1)
sns.distplot(df.matchDuration,ax=axs[0]);
sns.distplot(df.walkDistance,ax=axs[1]);

# %%
fig,axs=plt.subplots(1,2)
sns.distplot(df.matchDuration,ax=axs[0]);
sns.distplot(df.walkDistance,ax=axs[1]);

# %%
df.matchType.nunique()

# %%
df.matchType.value_counts()

# %% [markdown]
# # Find the Categorical column

# %%
df.select_dtypes(exclude=['number'])

# %% [markdown]
# # Plot a boxplot of ‘matchType’ vs ‘winPlacePerc’. Write your inferences

# %%
sns.barplot(df.matchType,df.killPoints);
plt.xticks(rotation=70);

# %% [markdown]
# # Interences:-
# The Normal-squad-fpp and normal-squad-fpp match types has the most kill points solo-fpp and solo match types has the less kill points.

# %% [markdown]
# # Plot a boxplot of ‘matchType’ vs ‘matchDuration’. Write your inferences

# %%
sns.barplot(df.matchType,df.weaponsAcquired);
plt.xticks(rotation=70);

# %% [markdown]
# # Inference:-
# In crashtpp and crashfpp match types weapons acquired by players are very less In normal-solo-fpp and normal-squad-fpp match types weapons acquired by players are more.

# %% [markdown]
# # Change the orientation of the above plot to horizontal

# %%
sns.boxplot(df.matchDuration,df.matchType);
plt.xticks(rotation=70);

# %% [markdown]
# # Add a new column called ‘KILL’ which contains the sum of following columns viz. headshotKills,teamKills, roadKills

# %%
df['KILL']=(df.headshotKills+df.roadKills+df.teamKills)
kd=pd.DataFrame(df[['headshotKills','roadKills','teamKills','KILL']])
print(kd.head())

# %% [markdown]
# # Round off column ‘winPlacePerc’ to 2 decimals

# %%
df['winPlacePerc']=round(df['winPlacePerc'],2)
df['winPlacePerc']

# %% [markdown]
# # Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean. Plot it on a histogram and comment on its distribution

# %%
x = []
for i in range(100):
    x.append(df['damageDealt'].sample(50).mean())
means = np.array(x)
sns.distplot(means);

# %% [markdown]
# **It's like a normal distribution in which mean is 0 and variance is 1**

# %% [markdown]
# # THANK YOU
