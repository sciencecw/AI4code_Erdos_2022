# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrHPLOi8Jmt2rNoaZUmYJUVgsSuhCKJRiZZQ&usqp=CAU)medium.com

# %%
# !pip install data-purifier==0.3.0

# %%
import datapurifier as dp
from datapurifier import Nlpeda, Nlpurifier

# %%
nlp_df = pd.read_csv("../input/dataset-accessibility-user-reviews/TextBlob_A11y_Labels.csv", header=None, encoding='latin-1')
nlp_df.columns = ["desc_id", "source_name", "review_text", "is_accessbility", "cleanText", "Polarity Score","sentiment"]

# %% [markdown]
# #Since NLP DataPurifier does Not show in the viewer, I made a print of the inside.

# %% [markdown]
# ![image.PNG](attachment:a0433ee9-bb8d-4021-9d70-9128f88003f4.PNG)

# %%
eda = Nlpeda(nlp_df, "cleanText", analyse="basic")
eda.df

# %%
eda = Nlpeda(nlp_df, "cleanText", analyse="word")
eda.unigram_df # for seeing unigram datfarame

# %% [markdown]
# #Another view of the inside, since it does Not appear in the viewer.

# %% [markdown]
# ![image.PNG](attachment:f778f201-c038-4345-86d1-c755680768ac.PNG)

# %% [markdown]
# #Acknowledgment
#
# "A Python library for Automated Exploratory Data Analysis, Automated Data Cleaning, and Automated Data Preprocessing For Machine Learning and Natural Language Processing Applications in Python."
#
# Automated EDA for NLP
#
# Automated Data Cleaning for NLP
#
# Automated EDA for Machine Learning
#
# Automated Report Generation for Machine Learning
#
# https://github.com/Elysian01/Data-Purifier
#
#
# That's all for now with NLP Data-Purifier.
