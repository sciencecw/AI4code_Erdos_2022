# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Load

# %%
df=pd.read_csv('../input/students-performance-in-exams/StudentsPerformance.csv')

# %%
df.head()

# %%
df.shape

# %%
df.describe()

# %% [markdown]
# #Install Dependencies

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Pandas DataFrame property: loc
#
# https://www.w3resource.com/pandas/dataframe/dataframe-loc.php

# %%
lineplot_data=df.loc[:10,['math score']]
display(lineplot_data)

# %% [markdown]
# #SeaBorn Lineplot

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))
# Add title
plt.title("Math Score")
# Add label for horizontal axis
plt.xlabel("Number of Students")
# Add label for vertical axis
plt.ylabel("Mark Scored")

sns.lineplot(data=lineplot_data,label='Student Math Score')

# %% [markdown]
# #Bar Charts and Heatmaps

# %%
df.index

# %%
barplot_data=df['reading score'][:10]
display(barplot_data)

# %%
plt.figure(figsize=(16,6))
plt.title('reading score'.title())
# Add label for horizontal axis
plt.xlabel("Number of Students")
# Add label for vertical axis
plt.ylabel("Mark Scored")
sns.barplot(x=barplot_data.index,y=barplot_data)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
df.head(10)

# %%
heatmap_data=df[['math score','reading score','writing score']][:10]
display(heatmap_data)

# %%
# heatmap_data.pivot(columns='reading score',values='writing score')

# %% [markdown]
# # Heat map - fmt example

# %%
# fmt='.1g'
# .1e = scientific notation with 1 decimal point (standard form)
# .2f = 2 decimal places
# .3g = 3 significant figures
# .4% = percentage with 4 decimal places

import numpy as np; 
np.random.seed(0)
import seaborn as sns; 
sns.set()
uniform_data = np.random.rand(6, 6)/100
ax = sns.heatmap(uniform_data,annot=True, fmt=".2%")

# %%
uniform_data = np.random.rand(6, 6)/100
ax = sns.heatmap(uniform_data,annot=True, fmt=".2g")

# %%
uniform_data = np.random.rand(6, 6)/100
ax = sns.heatmap(uniform_data,annot=True, fmt=".2f")

# %%
plt.figure(figsize=(16,6))
uniform_data = np.random.rand(6, 6)/100
ax = sns.heatmap(uniform_data,annot=True, fmt=".2e")

# %%
plt.figure(figsize=(16,6))
sns.heatmap(heatmap_data)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(heatmap_data,linewidths=8)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(heatmap_data,linewidths=8,linecolor='Orange',annot=True,fmt='d')

# %% [markdown]
# #cmap color reference
#
# https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %%
plt.figure(figsize=(16,6))
sns.heatmap(heatmap_data,linewidths=8,annot=True,fmt='d',cmap='Set1')

# %%
plt.figure(figsize=(16,6))
sns.heatmap(data=heatmap_data,linewidths=8,annot=True,fmt='d',cmap='twilight',cbar=False)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(data=heatmap_data,linewidths=8,annot=True,fmt='d',cmap='Set1',cbar=True,vmin=80,vmax=90)

# %% [markdown]
# #Correlation
#
# A correlation can range in value between –1 and 1:
#
#
# If the correlation is greater than 0, then as X increases Y
# increases and the two variables are said to be positively
# correlated. An r = 1 is perfect positive correlation.
#
#
#
# If the correlation is less than 0, then as X increases Y
# decreases and the two variables are said to be
# negatively correlated. An r = -1 is perfect negative
# correlation.
#
#
# If the correlation is 0 then there is no linear relationship
# between X and Y. The two variables are said to be
# uncorrelated. The correlation is 0 when the covariance
# of X and Y is 0.

# %%
heatmap_data1=heatmap_data.corr()
display(heatmap_data1)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(data=heatmap_data1,linewidths=8,annot=True,fmt='f',cmap='rainbow',cbar=True)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(data=heatmap_data1,linewidths=8,annot=True,fmt='f',cmap='cividis',cbar=True,vmin=-1,vmax=1)

# %% [markdown]
# From above Diagram we get
#
# The correlation is greater than 0 and close to 1 So it is  positively correlated.

# %%
dfCorr = heatmap_data1
filteredDf = dfCorr[((dfCorr >= .5) | (dfCorr <= -.5)) & (dfCorr !=1.000)]
plt.figure(figsize=(12,8))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %%
corr = heatmap_data1
kot = corr[corr>=.9]
plt.figure(figsize=(12,8))
sns.heatmap(kot, cmap="Greens", annot=True)

# %% [markdown]
# #Box Plots

# %%
display(df.shape)
df.head(2)

# %% [markdown]
# #Pandas Series property: iloc
#
# https://www.w3resource.com/pandas/series/series-iloc.php

# %%
boxplot_data=df.iloc[:10,5:8]
display(boxplot_data)

# %%
boxplot_data.describe()

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
plt.figure(figsize=(16,6))
sns.boxplot(data=boxplot_data)

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x=boxplot_data['math score'])

# %%
boxplot_data1=df[:10]
plt.figure(figsize=(16,6))
sns.boxplot(x='gender',y='math score',data=boxplot_data1)

# %%
boxplot_data1=df[:900]
plt.figure(figsize=(20,6))
sns.boxplot(hue='gender',x='reading score',y='math score',data=boxplot_data1)

# %%
boxplot_data1=df[(df['reading score']>80)& (df['math score']>80)]
display(boxplot_data1)

# %%
plt.figure(figsize=(20,6))
sns.boxplot(hue='gender',x='reading score',y='math score',data=boxplot_data1)

# %% [markdown]
# #seaborn.color_palette
#
# https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette
#
# https://matplotlib.org/stable/gallery/color/colormap_reference.html
#
# seaborn.color_palette(palette=None, n_colors=None, desat=None, as_cmap=False)

# %%
sns.color_palette("Set2")

# %%
sns.color_palette("flare", as_cmap=True)

# %%
boxplot_data2=df[(df['reading score'].isin(range(60,70)))& (df['math score'].isin(range(60,70)))]
display(boxplot_data2)

# %%
plt.figure(figsize=(20,6))
sns.boxplot(hue='race/ethnicity',x='reading score',y='math score',data=boxplot_data2,palette='Set2')

# %%
df['race/ethnicity'].unique()

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x='race/ethnicity',y='math score',data=boxplot_data2,palette='Set2'
            ,order=['group B', 'group C', 'group A', 'group D', 'group E'])

# %% [markdown]
# #Scatter Plots

# %%
df.head(2)

# %%
scatter_plot_data=df[:400]
display(scatter_plot_data)

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x=scatter_plot_data['reading score'],y=scatter_plot_data['writing score'])

# %%
scatter_plot_data.corr()

# %% [markdown]
# by above diagram Which show that Student reading-score increase Student writing-score also increase
#
# And also correlation value also prove's it
#
# To double-check the strength of this relationship, you might like to add a regression line

# %%
plt.figure(figsize=(16,6))
sns.regplot(x=scatter_plot_data['reading score'],y=scatter_plot_data['writing score'])

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x=scatter_plot_data['reading score'],y=scatter_plot_data['writing score'],hue=scatter_plot_data['gender'])

# %%
scatter_plot_data['gender'].unique()

# %%
scatter_plot_data.head(2)

# %%
# scatter_plot_data['gender'][scatter_plot_data['gender']=='male']=1
# scatter_plot_data['gender'][scatter_plot_data['gender']=='female']=0
# scatter_plot_data['gender'] = scatter_plot_data['gender'].map({'male': 1,'female': 0})
# import numpy as np
# scatter_plot_data.loc[:,'gender'] = np.where(scatter_plot_data.loc[:,'gender'] == 'male', 1, 0)

# %%
plt.figure(figsize=(20,6))
sns.lmplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data)

# %%
scatter_plot_data2=df[(df['reading score'].isin(range(60,80)))& (df['writing score'].isin(range(60,80)))]
display(scatter_plot_data2)

# %% [markdown]
# # design of the scatter plot to feature a categorical variable

# %%
plt.figure(figsize=(16,6))
sns.swarmplot(x=scatter_plot_data2['reading score'],y=scatter_plot_data2['writing score'])

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',data=scatter_plot_data2)

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data2)

# %%
scatter_plot_data3=df[(df['reading score'].isin(range(80,85)))& (df['writing score'].isin(range(80,90)))]
display(scatter_plot_data3)

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data3,style='test preparation course')

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data3,style='writing score')

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data3,size='parental level of education')

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data3,style='writing score',size='parental level of education')

# %%
plt.figure(figsize=(16,6))
sns.relplot(x='reading score',y='writing score',hue='gender',data=scatter_plot_data3,size='parental level of education',sizes=(100,300))

# %% [markdown]
# # Distributions

# %%
df.head(2)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.displot.html

# %%
dist_data=df

# %% [markdown]
# # FutureWarning: `distplot` is a deprecated function and will be removed in a future version.

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score')

# %% [markdown]
# From histogram we can tell Student get (60-80) marks in writing

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',bins=5)

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',hue='gender')

# %% [markdown]
# From above we can get Female score more high marks (60-100 range) in writing exam than male

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',hue='test preparation course')

# %% [markdown]
# From above we can get that those who completed the test preparation course getting high marks in writing exam (60-100 range)
#
# while who not completed the course get lower marks than completed student in writing exam

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',hue='test preparation course',col='test preparation course')

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='test preparation course',col='race/ethnicity')

# %% [markdown]
# From above diagram it is shown that Group C has highest completed and non completed course
#
# and also Seen previous Histogram diagram we have proven that Course Completed student get more mark in  written score

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='test preparation course',col='gender',hue='race/ethnicity',palette='hsv')

# %% [markdown]
# From above diagram we get that Female of Group C has higher count in completion and non completion of test preparation course

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='test preparation course',col='lunch',facet_kws={'despine':False})

# %%
plt.figure(figsize=(16,6))
# Histogram 
g=sns.displot(data=dist_data,x='gender',col='test preparation course')
for col_val ,ax in g.axes_dict.items():
    if col_val=='completed':
        ax.set_facecolor('Orange')
    if col_val=='none':
        ax.set_facecolor('MediumSeaGreen')

# %% [markdown]
# From above shaded diagram we came to know that most of the student didn't complete test preparation course So many student score less mark in written exam

# %%
dist_data['lunch']

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='test preparation course',hue='lunch',col='race/ethnicity',height=2,aspect=1.5)

# %% [markdown]
# As we all know that Group A score very less mark in writing
# From above diagram In addition we get that they didn't get standard lunch they get very low free/reduced lunch
# and Group C get Standard lunch in higher count than other group

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',kind='kde',fill=True)

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',kind='kde',hue='race/ethnicity')

# %% [markdown]
# From above diagram we get density of Group C  score is higher than all other group in writing exam
#
#
# So we can conclude the more people in Group C score high marks in writing exam
#
# From previous diagram it is proven that Group C student has highest number in test preparation course completed than other group

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',kind='kde',hue='race/ethnicity',col='race/ethnicity',fill=True,lw=5)

# %%
dist_data1=df[:10]
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data1,x='writing score',y='reading score')

# %%
dist_data1=df[:10]
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data1,x='writing score',y='reading score',kind='kde')

# %%
dist_data1=df[:10]
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data1,x='writing score',y='reading score',kind='kde',rug=True)

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',kind='kde',rug=True)

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',kind='kde',rug=True,rug_kws={'height':0.25})

# %% [markdown]
# # Empirical Distribution Function
#
# https://machinelearningmastery.com/empirical-distribution-function-in-python/
#
#
# k/n, where:
#
# “k” is the numbered observation (this is easy, it’s just 1, 2, 3, 4, 5…)
#
# “n” is the number in your sample. For this example, I have 50 observations, so I entered 1/50.

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.displot(data=dist_data,x='writing score',kind='ecdf') #0.0 to 1.0

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.histplot(data=dist_data['writing score'], kde=False)

# %%
plt.figure(figsize=(16,6))
# Histogram 
sns.histplot(data=df['writing score'], kde=True)

# %% [markdown]
# # Density plots

# %%
df.head(2)

# %%
plt.figure(figsize=(16,6))
# KDE plot 
sns.kdeplot(data=df,x='math score',shade=True)

# %%
plt.figure(figsize=(16,6))
# 2D KDE plot
sns.jointplot(x=df['math score'], y=df['reading score'], kind="kde")

# %%
plt.figure(figsize=(16,6))
# Histograms for each species
sns.kdeplot(data=df['math score'], label="math score", shade=True)
sns.kdeplot(data=df['reading score'], label="reading score", shade=True)
sns.kdeplot(data=df['writing score'], label="writing score",shade=True)

# Add title
plt.title("Student Scores")

# Force legend to appear
plt.legend()

# %% [markdown]
# #  Choosing Plot Types and Custom Styles

# %% [markdown]
# What have you learned?
#
#
# Since it's not always easy to decide how to best tell the story behind your data, we've broken the chart types into three broad
#
# categories to help with this.
#
#
# **Trends** - A trend is defined as a pattern of change.
#
# sns.lineplot - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
#
# **Relationship **- There are many different chart types that you can use to understand relationships between variables in your data.
#
# sns.barplot - Bar charts are useful for comparing quantities corresponding to different groups.
#
# sns.heatmap - Heatmaps can be used to find color-coded patterns in tables of numbers.
#
# sns.scatterplot - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#
# sns.regplot - Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
#
# sns.lmplot - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#
# sns.swarmplot - Categorical scatter plots show the relationship between a continuous variable and a categorical variable.
#
#
# **Distribution **- We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#
# sns.distplot - Histograms show the distribution of a single numerical variable.
#
# sns.kdeplot - KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#
# sns.jointplot - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable

# %% [markdown]
# #  Seaborn has five different themes
#
# (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks",
