# %% [markdown]
# <h1 align="center"> HR Analysis, Prediction and Visualization </b> </h1><br>

# %% [markdown]
# # I hope you find this kernel useful and your <font color='Orange'>UPVOTES</font> would be highly appreciated!

# %% [markdown]
# # <font color='Red'>Table of Contents:</font>
# 1. Importing the Library
# 2. Loading the Dataset
# 3. Check the Null Values using Visualization
# 4. Exploratory Data Analysis
#     - Numerical Value Visualization
#         - Pairplot
#         - Heatmap
#         - Countplot
#         - Hist Plot
#         ....
#     - Categorical Variable Visualization
# 5. Handling Categorical Variables
# 6. <font color='red'> Next Update Very Soon:</font>
#         -

# %% [markdown]
# ## 1. Importing Library

# %%
### importing important library

import numpy as np ## Matrix Multiplication
import pandas as pd  ## Exploratory Data Analysis
import matplotlib.pyplot as plt   ## Visualization
import seaborn as sns   ## Visualization

# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## 2. Loading the Dataset

# %%
#### Loading the Dataset

pd.set_option('display.max_columns', None)
data = pd.read_csv("../input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv")
data.head(10)   ### Print the top 10 rows

# %%
data.columns   ### print all COlumns

# %%
data.shape   ### print all rows and coluns

# %%
data.info()  ### All information of the dataset

# %%
data.describe().T

# %% [markdown]
# ## Checking the Null Values

# %%
data.isnull().sum()  ## Checking the Null Values using isnull finction

# %% [markdown]
# Our dataset No Null Values are present

# %%
#### Visualizing the null values using missingo function

import missingno as msno
msno.matrix(data)

# %%
msno.bar(data, color = 'y', figsize = (15,8))   #### Anathro method to visualizing the null values.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Numerical Value Visualization

# %%
data.head(3)

# %%
###### Important Numerical columns in our datasets

data1 = data[['Age','Attrition', 'DistanceFromHome','Education', 'JobLevel','JobSatisfaction','PerformanceRating','NumCompaniesWorked','Gender']]
data1.head()

# %%
### Pairplot using seaborn library
sns.pairplot(data1)

# %%
#### Heatmap using seabron libaray
plt.figure(figsize=(30, 30))
sns.heatmap(data.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15})

# %%
### Countplot

plt.subplots(figsize=(15,5))
sns.countplot(data.Age)

# %%
plt.subplots(figsize=(15,5))
sns.distplot(data['Age'])

# %%
plt.subplots(figsize=(15,5))
sns.countplot(data.Education)

# %%
plt.subplots(figsize=(15,5))
sns.countplot(data.NumCompaniesWorked)

# %%
plt.subplots(figsize=(15,5))
sns.countplot(data.PerformanceRating)

# %%
data['MonthlyIncome'].hist(color='green',bins=40,figsize=(15,8))

# %%
data['StandardHours'].hist(color='red',bins=40,figsize=(15,8))

# %% [markdown]
# ## Categorical Value Visualisation

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='Attrition', data = data)

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='Attrition', hue='Gender', data = data, palette='RdBu_r')

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='BusinessTravel', data=data)

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='BusinessTravel',hue='Gender', data=data)

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='BusinessTravel', hue='Attrition',data=data)

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='MaritalStatus', data=data)

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='MaritalStatus', hue='Gender', data=data)
plt.title('Marital Status')

# %%
#plt.subplots(figsize=(15,8))
fig = plt.gcf()
fig.set_size_inches(20,14)
sns.countplot(x='JobRole', data=data)

# %%
#plt.subplots(figsize=(15,8))
fig = plt.gcf()
fig.set_size_inches(20,14)
sns.countplot(x='JobRole', hue='Gender',data=data)
plt.title('Job Role Between Male and Female')

# %%
plt.subplots(figsize=(15,8))
sns.countplot(x='Gender',data=data)

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='EducationField', data=data)

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='EducationField', hue='Gender',data=data)

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='Department', data=data)

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='Department', hue='Gender',data=data)

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='Department', hue='Attrition',data=data)

# %%
sns.catplot(x="OverTime", y="Age", kind="swarm", data=data)

# %%
data.head(4)

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Education',y='Age',data=data,palette='winter')

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='PercentSalaryHike',y='Age',data=data,palette='winter')

# %% [markdown]
# ## Handling Categorical Variables

# %% [markdown]
# ## <font color='orange'> I am working on this dataset so I will keep updating it</font>
#
# # <font color='Red'> Please Upvote if you found these helpful :)</font>
