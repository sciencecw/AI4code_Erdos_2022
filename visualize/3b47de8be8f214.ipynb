# %%
import pandas as pd
df=pd.read_csv('../input/traded-energy-share-domestic/traded-energy-share-domestic.csv')
df

# %% [markdown]
# ![ai](https://d346xxcyottdqx.cloudfront.net/wp-content/uploads/2018/07/energy-markets.jpg)

# %%
# !pip install dataprep

# %%
from dataprep.eda import plot, plot_correlation, create_report, plot_missing

# %%
plot(df)

# %%
create_report(df)
