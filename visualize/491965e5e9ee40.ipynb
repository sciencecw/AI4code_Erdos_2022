# %% [markdown]
# ## My First Steps on Machine Learning

# %%
import numpy as np 
import pandas as pd 


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## 0.Train data
# ### 0.1. read train data

# %%
train_data = pd.read_csv("/kaggle/input/titanic/train.csv")
train_data.head()

# %% [markdown]
# ### 0.2. checking null
# - Age 177, Cabin 687, Emabrked 2

# %%
train_data.isnull().sum().sort_values(ascending = False)

# %% [markdown]
# ## 1. Data EDA
# ### 1.1 EDA

# %%
train_data = train_data[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]

# %%
train_data['Age'].fillna(train_data['Age'].mean(),inplace=True)
train_data.head()

# %%
train_data.dropna(inplace=True)

# %%
train_data.isnull().sum().sort_values(ascending = False)

# %%
train_data.loc[(train_data['Sex'] == 'male'), 'Sex']="0"
train_data.loc[(train_data['Sex'] == 'female'), 'Sex']="1"

# %%
train_data.head()

# %%
test_data = pd.read_csv("/kaggle/input/titanic/test.csv")
test_data.head()

# %%
test_data = test_data[['PassengerId','Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]

# %%
test_data.loc[(test_data['Sex'] == 'male'), 'Sex']="0"
test_data.loc[(test_data['Sex'] == 'female'), 'Sex']="1"

# %%
test_data.isnull().sum()

# %%
test_data = test_data.fillna(test_data.mean())

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["Survived"]

features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

# %%
output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('my_submission.csv', index=False)
print("Your submission was successfully saved!")

# %%
output.head()
