# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# Abstract—As skin cancer is one of the most frequent cancers globally, accurate, non-invasive dermoscopy-based diagnosis becomes
# essential and promising. A task of the Part 3 of the ISIC Skin Image Analysis Challenge@MICCAI 2018 is to predict seven disease
# classes with skin lesion images, including melanoma (MEL), melanocytic nevus (NV), basal cell carcinoma (BCC), actinic keratosis /
# Bowens disease (intraepithelial carcinoma) (AKIEC), benign keratosis (solar lentigo / seborrheic keratosis / lichen planus-like keratosis)
# (BKL), dermatofibroma (DF) and vascular lesion (VASC) as defined by the International Dermatology Society [1], [2]. In this work, we
# design the WonDerM pipeline, that resamples the preprocessed skin lesion images, builds neural network architecture fine-tuned with
# segmentation task data (the Part 1), and uses an ensemble method to classify the seven skin diseases. Our model achieved an
# accuracy of 0.899 and 0.785 in the validation set and test set, respectively.
# Index Terms—Dermatology, Skin Lesion Classification, Computer Vision and Pattern Recognition, Deep Learning, Inductive Transfer
# Learning

# %%
data=pd.read_csv("../input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv")
data.head()

# %%
data.info()

# %%
 data.drop(['lesion_id', 'image_id'], axis=1,inplace=True)
data.info()

# %%
data.age.value_counts()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data.age)
plt.title("Age of cancer patient",size=20)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data.sex)
plt.title("gender of cancer patient",size=15)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='sex',hue='age',data=data)
plt.legend(loc='best')
plt.title("Age & gender of cancer patient",size=15)
plt.show()

# %%
data.columns

# %%
data.dx.unique()

# %%
data.dx_type.unique()

# %%
data.localization.unique()

# %%
data.localization.value_counts()

# %%
labels=data.localization.value_counts().index
sizes=data.localization.value_counts().values
plt.figure(figsize=(11,11))
plt.pie(sizes,labels=labels,autopct="%1.f%%")
plt.title("cancer location",size=25)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=labels,y=sizes)
plt.show()

# %%
data.dx.value_counts()

# %%
labels1=data.dx.value_counts().index
sizes1=data.dx.value_counts().values
plt.figure(figsize=(11,11))
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%")
plt.title("seven most common types of skin cancer",size=25)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=labels1,y=sizes1)
plt.show()

# %% [markdown]
# including melanoma (MEL), melanocytic nevus (NV), basal cell carcinoma (BCC), actinic keratosis /
# Bowens disease (intraepithelial carcinoma) (AKIEC), benign keratosis (solar lentigo / seborrheic keratosis / lichen planus-like keratosis)
# (BKL), dermatofibroma (DF) and vascular lesion (VASC)

# %%
plt.figure(figsize=(15,10))
sns.countplot(x="dx",hue="sex",data=data)
plt.show()
